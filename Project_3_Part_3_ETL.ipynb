# %%
import pandas as pd
import numpy as np
pymysql.install_as_MySQLdb()
import pymysql
from sqlalchemy_utils import create_database, database_exists
from sqlalchemy import create_engine

# %%
username = "root"
password = "Henda2022"
db_name = 'movies'
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"
engine = create_engine(connection)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/movies)

# %%
create_database(connection)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:1910, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1909     if not evt_handled:
# -> 1910         self.dialect.do_execute(
#    1911             cursor, statement, parameters, context
#    1912         )
#    1914 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# ...

# %%
database_exists(connection)
# Out:
# True

# %%
# LOADING DATA
title_basics = pd.read_csv('Data/title_basics.csv.gz') 
title_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0082328     movie                                 Embodiment of Evil
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                        Lives of Performers        0       2016      NaN
# 3                 The Other Side of the Wind        0       2018      NaN
# 4                      Encarnação do Demônio        0       2008      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
title_ratings = pd.read_csv('Data/title_ratings.csv.gz')
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2004
# 1  tt0000002            5.8       269
# 2  tt0000005            6.2      2685
# 3  tt0000006            5.0       183
# 4  tt0000007            5.4       840

# %%
# LOADING DATA
tmdb_data = pd.read_csv('Data/tmdb_results_combined.csv.gz') 
tmdb_data.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
# column with list of genres
title_basics['genres_split'] = title_basics['genres'].str.split(',')

# %%
title_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0082328     movie                                 Embodiment of Evil
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                        Lives of Performers        0       2016      NaN
# 3                 The Other Side of the Wind        0       2018      NaN
# 4                      Encarnação do Demônio        0       2008      NaN
#
#    runtimeMinutes                  genres                genres_split
# ...

# %%
exploded_genres = title_basics.explode('genres_split')
exploded_genres
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 0       tt0035423     movie
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0068865     movie
# ...           ...       ...
# 148666  tt9916270     movie
# 148667  tt9916362     movie
# 148667  tt9916362     movie
# 148668  tt9916538     movie
# 148669  tt9916730     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 0                                          Kate & Leopold
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                                     Lives of Performers
# ...                                                   ...
# 148666                           Il talento del calabrone
# 148667                                              Coven
# 148667                                              Coven
# ...

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
# Create a new title_genres table
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0068865        Drama

# %%
# Create a genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
# Replace string genres with integer IDs
# Drop the 'genres_split' column
title_basics['genre_id'] = title_basics['genres_split'].replace(genre_map)
title_basics = title_basics.drop(columns='genres_split')

# %%
title_genres
# Out:
#            tconst genres_split
# 0       tt0035423       Comedy
# 0       tt0035423      Fantasy
# 0       tt0035423      Romance
# 1       tt0062336        Drama
# 2       tt0068865        Drama
# ...           ...          ...
# 148666  tt9916270     Thriller
# 148667  tt9916362        Drama
# 148667  tt9916362      History
# 148668  tt9916538        Drama
# 148669  tt9916730        Drama
#
# [258534 rows x 2 columns]

# %%
# Convert the genre map dictionary into a DataFrame
genres = pd.DataFrame(genre_map.items(), columns=['Genre_Name', 'Genre_ID'])
genres.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
# Dele unnecessary information
title_basics = title_basics.drop(columns=['originalTitle', 'isAdult', 'titleType', 'genres', 'endYear'])

# %%
title_basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0068865                                Lives of Performers
# 3       tt0069049                         The Other Side of the Wind
# 4       tt0082328                                 Embodiment of Evil
# ...           ...                                                ...
# 148665  tt9916190                                          Safeguard
# 148666  tt9916270                           Il talento del calabrone
# 148667  tt9916362                                              Coven
# 148668  tt9916538                                Kuambil Lagi Hatiku
# 148669  tt9916730                                             6 Gunn
#
#         startYear  runtimeMinutes                       genre_id
# 0            2001             118     [Comedy, Fantasy, Romance]
# ...

# %%
title_basics['genre_id'] = title_basics['genre_id'].astype(str)
title_basics['genre_id'] = title_basics['genre_id'].str.replace("[",'')
title_basics['genre_id'].head()
# Out:
# C:\Users\x474437\AppData\Local\Temp\ipykernel_12156\4094571795.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   title_basics['genre_id'] = title_basics['genre_id'].str.replace("[",'')
# 0    'Comedy', 'Fantasy', 'Romance']
# 1                           'Drama']
# 2                           'Drama']
# 3                           'Drama']
# 4                          'Horror']
# Name: genre_id, dtype: object

# %%
title_basics['genre_id'] = title_basics['genre_id'].str.replace("]",'')
title_basics['genre_id'].head()
title_basics.head()
# Out:
# C:\Users\x474437\AppData\Local\Temp\ipykernel_12156\1205219983.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   title_basics['genre_id'] = title_basics['genre_id'].str.replace("]",'')
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold       2001
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...       2020
# 2  tt0068865                                Lives of Performers       2016
# 3  tt0069049                         The Other Side of the Wind       2018
# 4  tt0082328                                 Embodiment of Evil       2008
#
#    runtimeMinutes                        genre_id
# 0             118  'Comedy', 'Fantasy', 'Romance'
# 1              70                         'Drama'
# ...

# %%
# Select specific columns from tmdb_data DataFrame
tmdb_data = tmdb_data[['imdb_id', 'budget', 'revenue', 'certification']]
tmdb_data.head()
# Out:
#      imdb_id      budget  revenue certification
# 0          0         NaN      NaN           NaN
# 1  tt0113026  10000000.0      0.0           NaN
# 2  tt0113092         0.0      0.0           NaN
# 3  tt0116391         0.0      0.0           NaN
# 4  tt0116748         0.0      0.0           NaN

# %%
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = title_basics['tconst'].fillna('').map(len).max()
title_len = title_basics['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_basics = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    "genre_id":Text(title_len+1),
    'startYear':Float(),
    'runtimeMinutes':Integer()}

# %%
## Calculate max string lengths for object columns
key_len1 = title_ratings['tconst'].fillna('').map(len).max()
df_ratings = {
    "tconst": String(key_len1+1),
    'averageRating' :Float(),
    'numVotes' :Integer()}

# %%
## Calculate max string lengths for object columns
title_len1 = tmdb_data['imdb_id'].fillna('').map(len).max()
df_tmdb = {
    'imdb_id': Text(title_len1+1),
    'budget': Float(),
    'revenue': Float(),
    'certification': Text(title_len+1)}

title_len3 = genres['Genre_Name'].fillna('').map(len).max()
df_genres = {
    'Genre_ID': Integer(),
    'Genre_Name': Text(title_len3+1)}

# %%
title_basics.to_sql('title_basics',engine,dtype=df_basics,if_exists='replace',index=False)
# Out:
# 148670

# %%
genres.to_sql('genres',engine,dtype=df_genres,if_exists='replace',index=False)
# Out:
# 25

# %%
title_ratings.to_sql('title_ratings',engine,dtype=df_ratings,if_exists='replace',index=False)
# Out:
# 513077

# %%
tmdb_data.to_sql('tmdb_data',engine,dtype=df_tmdb,if_exists='replace',index=False)
# Out:
# 4595

# %%
title_genres.to_sql('title_genres',engine,if_exists='replace',index=False)
# Out:
# 258534

# %%
q = '''SHOW TABLES'''
pd.read_sql(q,engine)
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3    title_ratings

# %%
q = '''SELECT *
FROM title_basics
LIMIT 5;'''
pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0068865                                Lives of Performers     2016.0
# 3  tt0069049                         The Other Side of the Wind     2018.0
# 4  tt0082328                                 Embodiment of Evil     2008.0
#
#    runtimeMinutes                        genre_id
# 0             118  'Comedy', 'Fantasy', 'Romance'
# 1              70                         'Drama'
# 2              90                         'Drama'
# 3             122                         'Drama'
# 4              94                        'Horror'

# %%
q = '''SELECT *
FROM title_genres
LIMIT 5;'''
pd.read_sql(q, engine)
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 1  tt0035423      Fantasy
# 2  tt0035423      Romance
# 3  tt0062336        Drama
# 4  tt0068865        Drama

# %%
q = '''SELECT *
FROM title_ratings
LIMIT 5;'''
pd.read_sql(q, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2004
# 1  tt0000002            5.8       269
# 2  tt0000005            6.2      2685
# 3  tt0000006            5.0       183
# 4  tt0000007            5.4       840

# %%
q = '''SELECT *
FROM genres
LIMIT 5;'''
pd.read_sql(q, engine)
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
q = '''SELECT *
FROM tmdb_data
LIMIT 5;'''
pd.read_sql(q, engine)
# Out:
#      imdb_id      budget  revenue certification
# 0          0         NaN      NaN          None
# 1  tt0113026  10000000.0      0.0          None
# 2  tt0113092         0.0      0.0          None
# 3  tt0116391         0.0      0.0          None
# 4  tt0116748         0.0      0.0          None
